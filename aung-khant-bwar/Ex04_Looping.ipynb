# %% [markdown]
# <a href="https://colab.research.google.com/github/myothida/PythonProgramming/blob/main/Ex4_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
sent = "Hello Python"

stop = len(sent)

start = 0
while start < stop:
    print(sent[start])
    start += 1
# Out:
# H
# e
# l
# l
# o
#
# P
# y
# t
# h
# o
# n

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
wrong_input = True 

while wrong_input:
    inpt = float(input("Pls enter a weight in kg: "))
    if inpt < 0:
        print("Cannot be less than 0, re enter the number: ")
    else:
        converted = inpt * 2.2 
        print(f"{inpt} kg is {converted} lb")
        wrong_input = False
# Out:
# Pls enter a weight in kg:  -1
# Cannot be less than 0, re enter the number:
# Pls enter a weight in kg:  233
# 233.0 kg is 512.6 lb

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
stop = False 
score_card = []

while not stop:
    score = float(input("Enter your test score. If you want to stop enter negative number. "))
    
    if score > 0:
        score_card.append(score)
    if score < 0:
        avg = sum(score_card) / len(score_card)
        for score in score_card:
            if score >= 90:
                print(f"You got {score} and it's A!!!")
        print(f"Your average score is {avg}")
        stop = True
# Out:
# Enter your test score. If you want to stop enter negative number.  10
# Enter your test score. If you want to stop enter negative number.  90
# Enter your test score. If you want to stop enter negative number.  100
# Enter your test score. If you want to stop enter negative number.  110
# Enter your test score. If you want to stop enter negative number.  -1
# You got 90.0 and it's A!!!
# You got 100.0 and it's A!!!
# You got 110.0 and it's A!!!
# Your average score is 77.5

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
string = "Hello Python"
char = "p"

for i, c in enumerate(string):
    if char == c.lower():
        print(f"{char} is at the index {i}")
# Out:
# p is at the index 6

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
l_1 = [1, 1, 1, 1, 1, 0, 0]
l_2 = [1, 1, 1, 1, 1, 1, 1]

for i, n in enumerate(l_1):
    if n == 0:
        l_1[i] = 1
    else:
        print("There are no zero in the list")
        
l_1
# Out:
# There are no zero in the list
# There are no zero in the list
# There are no zero in the list
# There are no zero in the list
# There are no zero in the list
# [1, 1, 1, 1, 1, 1, 1]
